# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.random import randn,randint,uniform,sample

# %% [markdown]
# ### Creating a DataFrame and Series

# %%
df = pd.DataFrame(randn(1000),index = pd.date_range('2020-04-26', periods = 1000))
ts = pd.Series(randn(1000),index = pd.date_range('2020-04-26', periods =1000))

# %%
df
# Out:
#                    0
# 2020-04-26 -0.600754
# 2020-04-27 -0.374681
# 2020-04-28  0.993904
# 2020-04-29  0.494470
# 2020-04-30  0.670996
# ...              ...
# 2023-01-16  0.030010
# 2023-01-17 -0.122619
# 2023-01-18  0.393751
# 2023-01-19  0.089600
# 2023-01-20  0.169363
#
# [1000 rows x 1 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Take first 5 rows

# %%
ts.head()
# Out:
# 2020-04-26   -0.633819
# 2020-04-27    1.035200
# 2020-04-28   -1.002361
# 2020-04-29   -0.538072
# 2020-04-30    0.133585
# Freq: D, dtype: float64

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#                    0
# 2020-04-26 -0.600754
# 2020-04-27 -0.374681
# 2020-04-28  0.993904
# 2020-04-29  0.494470
# 2020-04-30  0.670996

# %% [markdown]
# ### Plot time series using pandas inbuilt .plot() function

# %%
ts.plot(figsize=(10,5))

# %% [markdown]
# ### To plot time series using matplotlib use plt

# %%
plt.plot(ts)

# %% [markdown]
# ### Plot data frame

# %%
df.plot()

# %% [markdown]
# ### load_dataset function to download inbuilt sample datasets from seaborn .

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Axis subplot iri can be represent by

# %%
iri = iris.plot(figsize=(15,5),title = 'Iris Data Set')
iri.set_xlabel('X')
iri.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Plot histogram graph

# %%
ts.plot(kind ='hist')

# %% [markdown]
# ### Plot dataframe '0 th' location data
#
# ### First choose data using .iloc[ ] function and then plot it using .plot() function.

# %%
df.iloc[0].plot(kind='bar')

# %% [markdown]
# ### Plot Iris Data in bar form

# %%
iris.plot(kind = 'bar')

# %% [markdown]
# ### Lets observe only 0 index row or first row  --

# %%
iris.iloc[0].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1667280aea5d> in <module>
# ----> 1 iris.iloc[0].plot(kind='bar')
#
# c:\python38\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
# ...

# %% [markdown]
# ### You can see it shows type error : no numeric data to plot lets observe it.In Data Frame to point any location we use iloc function.You can see how we do slicing using iloc[ ] function in my Pandas-Module-For-Beginner-Imdb-Example git repository.

# %%
iris.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %% [markdown]
# ### You can checkout above that dtype is 'object' so to remove this object from dataframe we use 'drop' function.

# %%
#remove species coulumn
df = iris.drop(['species'],axis = 1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ### Now if you plot iris dataset bar polt than no error occure because we drop object datatype('species') using .drop( ) function.

# %%
df.iloc[0].plot(kind='bar')

# %% [markdown]
# ### Load titanic DataSet Example using seaborn or sns

# %%
#titanic data set available in seaborn so load it
titanic = sns.load_dataset('titanic')

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Plot a specific  column data

# %%
titanic['pclass'].plot(kind = 'hist')
plt.show()

# %% [markdown]
# ### Generate random no DataFrame

# %%
ndf = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
ndf
# Out:
#           a         b         c         d
# 0 -0.347520  0.297382 -2.133849 -1.834691
# 1 -0.067320 -0.271481 -0.531994  0.007546
# 2 -1.397361  2.339108  0.823882 -1.058407
# 3 -0.469660  0.534079  0.559797 -0.654440
# 4  1.420875 -1.023299 -1.199757  1.541755
# 5 -1.061197 -0.330018  1.467517  0.559875
# 6  0.385242  0.888894  0.337210  0.706242
# 7 -1.702894 -0.565929 -0.407267 -0.983154
# 8 -0.626808  0.558398 -0.044255 -0.061105
# 9  1.949440  0.214581  0.228949 -0.099499

# %% [markdown]
# ### Plot bar plot in stacked form

# %%
ndf.plot.bar(stacked=True)

# %% [markdown]
# ### Plot horizontal graph

# %%
ndf.plot(kind='barh', stacked =True)

# %%
ndf.plot.bar(stacked=True)

# %%
iris.plot(kind='hist')

# %%
iris.plot.hist(stacked=True,bins=10)

# %% [markdown]
# ### More bins no.

# %%
iris.plot.hist(stacked=True,bins=70)

# %% [markdown]
# ### To plot in horizontal from put orientation = 'horizontal'

# %%
iris.plot.hist(stacked=True,bins=70,orientation='horizontal')

# %% [markdown]
# ### taking difference of sepal_width column values using .diff() function

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked=True,bins=80)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Taking difference with respect to axis=0

# %%
df.diff(axis=0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             NaN          NaN           NaN          NaN
# 1            -0.2         -0.5           0.0          0.0
# 2            -0.2          0.2          -0.1          0.0
# 3            -0.1         -0.1           0.2          0.0
# 4             0.4          0.5          -0.1          0.0
# ..            ...          ...           ...          ...
# 145           0.0         -0.3          -0.5         -0.2
# 146          -0.4         -0.5          -0.2         -0.4
# 147           0.2          0.5           0.2          0.1
# 148          -0.3          0.4           0.2          0.3
# 149          -0.3         -0.4          -0.3         -0.5
#
# [150 rows x 4 columns]

# %%
df.diff().plot(kind='hist',stacked=True)

# %% [markdown]
# ### We can plot above graph by directly using .hist( ) function, alpha=0.5 represent 50 % of transparency of graph

# %%
df.diff().hist(color='g',alpha=0.5,figsize = (10,10))
# Out:
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %% [markdown]
# ### Box plot

# %%
color = {'boxes':'g','whiskers':'r'}

df.plot(kind='box',vert=True,color=color)
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Area Plot

# %%
df.plot.area(stacked=True)

# %% [markdown]
# ### When stacked=False

# %%
df.plot.area(stacked=False)

# %% [markdown]
# ### Scatter plot

# %%
df.plot.scatter(x='sepal_length',y='petal_length')

# %%
ax = df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
# Out:
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %% [markdown]
# ### Plot sepal_length and petal_length(Green)
# ### and sepal_width and petal_width(blue) in same graph

# %%
ax = df.plot.scatter(x='sepal_length',y='petal_length',label='length',c='g')
df.plot.scatter(x='sepal_width',y='petal_width',label='width',ax=ax,color='b')

# %% [markdown]
# ### s = df['petal_length']*50) represent size of dots.
# ### c = 'sepal_length' means sepal_length and petal_length distribution change with respect to sepal_length

# %%
df.plot.scatter(x='sepal_length',y='petal_length',label='length',c='sepal_length',s=df['petal_length']*50)

# %% [markdown]
# ### Plot hexbin

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10,C='sepal_length')

# %%
d = df.iloc[0]

# %%
d.plot.pie(figsize=(3,3))

# %% [markdown]
# ###If you want to plot so many rows and columns than how you do that?

# %%
# .T REPRESENT TRANSPOSE OF DataFrame
k = df.head(2).T
(k)
# Out:
#                 0    1
# sepal_length  5.1  4.9
# sepal_width   3.5  3.0
# petal_length  1.4  1.4
# petal_width   0.2  0.2

# %%
 k.plot.pie(subplots=True,figsize=(10,10))
# Out:
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
k.plot.pie(subplots=True,figsize=(15,15),autopct='%.2f',fontsize=16)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1F055EF8>,
# ...
#       dtype=object)

# %% [markdown]
# ### How to cut this pieplot?

# %%
series = pd.Series([0.2]*4,index=['s','h','u','b'],name='pie_plot')
series
# Out:
# s    0.2
# h    0.2
# u    0.2
# b    0.2
# Name: pie_plot, dtype: float64

# %%
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1F259730>,
# ...
#       dtype=object)

# %% [markdown]
# ### Replace diagonal elements from kernel Density Element plot

# %%
scatter_matrix(df,figsize=(10,10),diagonal='kde',color='r')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1EFE4100>,
# ...
#       dtype=object)

# %%
ts.plot.kde()

# %%
ts.describe()
# Out:
# count    1000.000000
# mean        0.004157
# std         1.010229
# min        -3.684962
# 25%        -0.694092
# 50%         0.013737
# 75%         0.651343
# max         3.592370
# dtype: float64

# %%
##it plots the curve in the form of fourier cofficient
from pandas.plotting import andrews_curves

# %%
df['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
andrews_curves(df,'sepal_width')

# %% [markdown]
# ### To insert style in the plot we can add style tag

# %%
ts.plot(style='g--',label='Series',legend=True,figsize=(10,5))

# %%
#plotting iris data
df.plot(legend=False )

# %%
p=iris

# %%
y = p.drop(['sepal_length','petal_length'],axis=1)
y
# Out:
#      sepal_width  petal_width    species
# 0            3.5          0.2     setosa
# 1            3.0          0.2     setosa
# 2            3.2          0.2     setosa
# 3            3.1          0.2     setosa
# 4            3.6          0.2     setosa
# ..           ...          ...        ...
# 145          3.0          2.3  virginica
# 146          2.5          1.9  virginica
# 147          3.0          2.0  virginica
# 148          3.4          2.3  virginica
# 149          3.0          1.8  virginica
#
# [150 rows x 3 columns]

# %%
y.plot(legend=True)

# %%
x = p.drop(['sepal_width','petal_width'],axis=1)
x
# Out:
#      sepal_length  petal_length    species
# 0             5.1           1.4     setosa
# 1             4.9           1.4     setosa
# 2             4.7           1.3     setosa
# 3             4.6           1.5     setosa
# 4             5.0           1.4     setosa
# ..            ...           ...        ...
# 145           6.7           5.2  virginica
# 146           6.3           5.0  virginica
# 147           6.5           5.2  virginica
# 148           6.2           5.4  virginica
# 149           5.9           5.1  virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# ### secondary_y = True means curve starts from right side

# %%
y.plot(figsize=(10,5))
x.plot(figsize=(5,5),secondary_y=True)

# %% [markdown]
# ### Plot sepal_width ,petal_width from left side and sepal_length, petal_length from right side

# %%
ax = y.plot(figsize=(10,5))
x.plot(figsize=(10,5),secondary_y=True,ax=ax)

# %% [markdown]
# ### sharex = Flase means every subplot has its own x axis and layout(2,2) represent subplot in form of 2x2 matrix

# %%
p.plot(subplots = True,sharex = False,layout=(2,2))
plt.tight_layout()
# Out:
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# c:\python38\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...
